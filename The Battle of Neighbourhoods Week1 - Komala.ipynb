# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# The land Down Under has quite the passion and love for Indian restaurants and Indian cuisine. So it comes as no big surprise that Indian cuisine fan base is growing steadily from the 1960s, the time when the Aussies had begun their travel to India.
#
# Besides the obvious reason of being amazingly delicious, growth of Indian cuisine’s popularity is also due to the increase in Indians migrating to Australia and the sizeable presence of the Indian community here.

# %% [markdown]
# ### 1.2 Problem & Interest

# %% [markdown]
# This project aims to provide all those Indian food lovers a place to gain insights about the location of their favourite Indian restaurants and grocery stores in the greater Sydney area.

# %% [markdown]
# ## 2. Data Acquisition and Processing

# %% [markdown]
# Sydney Metropolitan Area can be broadly classified into three regions and a total of 689 suburbs. In order to segment the suburbs and explore them, a dataset that contains the 3 regions and the suburbs that exist in each region as well as the the latitude and longitude coordinates of each suburb is needed.

# %% [markdown]
# ### 2.1 Data Sources

# %% [markdown]
# The data needed for this analysis is being sourced from multiple locations as stated below:
#
# - List of Sydney suburbs along with their postcodes will be obtained from the below URL:
#
#     https://www.intosydneydirectory.com.au/sydney-postcodes.php
#
#
# - Training Services NSW provides the regional classification of Sydney Metropolitan Area and their mapping to the postcodes below:
#
#     https://www.training.nsw.gov.au/about_us/postcodes_byregion.html
#
#
# - And the latitude and longitude co-ordinates for Australian postcodes is found in the link below:
#
#     http://www.corra.com.au/australian-postcode-location-data/
#
#
# - Indian restaurants and grocery stores location in every Sydney suburb will be obtained using Foursquare API

# %% [markdown]
# ### 2.2 Data Processing

# %% [markdown]
# To obtain the list of Sydney metropolitan suburbs including their region, postcode, latitude and longitude information in single table, data from each of the above mentioned sources had to be downloaded separately and combined into one file.  While the data was extracted manually into spreadsheets, combining the different datasets was done using the VLOOKUP function and the merged data was saved in a csv file.

# %% [markdown]
# ##### Below I will load the processed csv file and transform the data into a pandas dataframe for further analysis.

# %% [markdown]
# Before I commence loading the file I will download all the dependencies that are needed to load and explore the data first.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2p-h14c3975_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes credentials.
# Removing those credentials before for sharing the notebook.

# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_sydney_suburbs = pd.read_csv(body)
df_sydney_suburbs.head()
# Out:
#                       Region         Suburb  Postcode   Latitude   Longitude
# 0  Central & Northern Sydney     Barangaroo      2000 -33.855601  151.208220
# 1  Central & Northern Sydney    Dawes Point      2000 -33.855601  151.208220
# 2  Central & Northern Sydney      Haymarket      2000 -33.855601  151.208220
# 3  Central & Northern Sydney  Millers Point      2000 -33.877718  151.205723
# 4  Central & Northern Sydney         Sydney      2000 -33.867139  151.207114

# %% [markdown]
# ##### Making sure that the resulting dataframe includes all 3 regions and 689 suburbs..

# %%
print('The dataframe has {} regions and {} suburbs.'.format(
        len(df_sydney_suburbs['Region'].unique()),
        df_sydney_suburbs.shape[0]
    )
)
# Out:
# The dataframe has 3 regions and 689 suburbs.

# %% [markdown]
# ##### Using geopy library to get the latitude and longitude values of Sydney City

# %%
address = 'Sydney, NSW'

geolocator = Nominatim(user_agent="syd_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Sydney are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Sydney are -33.8548157, 151.2164539.

# %% [markdown]
# ##### Creating a map of Sydney with suburbs superimposed on top for visualization

# %%
# create map of Sydney using latitude and longitude values
map_sydney = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, region, suburb in zip(df_sydney_suburbs['Latitude'], df_sydney_suburbs['Longitude'], df_sydney_suburbs['Region'], df_sydney_suburbs['Suburb']):
    label = '{}, {}'.format(suburb, region)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sydney)  
    
map_sydney
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Below I utilize the Foursquare API to explore the suburbs and segment them.

# %%
CLIENT_ID = 'XXXX' # removing the Foursquare credentials for sharing the notebook
CLIENT_SECRET = 'XXXX' # removing the Foursquare credentials for sharing the notebook
VERSION = '20180605' # Foursquare API version
LIMIT = 100
#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# ##### Exploring my resident suburb in the dataframe..

# %% [markdown]
# Getting the suburb's name..

# %%
df_sydney_suburbs.loc[313, 'Suburb']
# Out:
# 'Parramatta'

# %% [markdown]
# Getting the suburb's latitude and longitude values..

# %%
suburb_latitude = df_sydney_suburbs.loc[313, 'Latitude'] # suburb latitude value
suburb_longitude = df_sydney_suburbs.loc[313, 'Longitude'] # suburb longitude value

suburb_name = df_sydney_suburbs.loc[313, 'Suburb'] # suburb name

print('Latitude and longitude values of {} are {}, {}.'.format(suburb_name, 
                                                               suburb_latitude, 
                                                               suburb_longitude))
# Out:
# Latitude and longitude values of Parramatta are -33.822427000000005, 151.008961.

# %% [markdown]
# Defining a query to search for Indian food related venues that is within 750 metres from Barangaroo

# %%
search_query = 'Indian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %% [markdown]
# Defining the corresponding URL..

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, suburb_latitude, suburb_longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LIPOB1ZHS4HTENRJ41X3B0XIZUMC0NZFOAOKZA200S03RIKJ&client_secret=WYWHPQY1TPFAKCJXY2FN4JNEXQOQ2LBDF40FKGA3Z11CSDLW&ll=-33.822427000000005,151.008961&v=20180605&query=Indian&radius=500&limit=100'

# %% [markdown]
# Sending the GET request and examining the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ccf3ceb9fb6b7571a79795a'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4cd52943a5b34688b83a8c50',
#     'location': {'address': '91 Wigram St',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 217,
#      'formattedAddress': ['91 Wigram St', 'Harris Park NSW 2150', 'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.820522,
#        'lng': 151.00948}],
#      'lat': -33.820522,
#      'lng': 151.00948,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': 'Taj Indian Sweets & Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '54135bf5e4b08f3d2429dfde',
#       'name': 'South Indian Restaurant',
#       'pluralName': 'South Indian Restaurants',
#       'primary': True,
#       'shortName': 'South Indian'}],
#     'hasPerk': False,
#     'id': '5af7bd34838e59002c67158b',
#     'location': {'address': '42 Marion st,',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 56,
#      'formattedAddress': ['42 Marion st,',
#       'Harris Park NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.82222,
#        'lng': 151.0084}],
#      'lat': -33.82222,
#      'lng': 151.0084,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': 'Amaravathi Indian Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '530051d7498ef1d57b83a062',
#     'location': {'address': '53 Marion St',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'country': 'Australia',
#      'crossStreet': 'Harris Park',
#      'distance': 61,
#      'formattedAddress': ['53 Marion St (Harris Park)',
#       'Sydney NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.82226632305128,
#        'lng': 151.0083261621207}],
#      'lat': -33.82226632305128,
#      'lng': 151.0083261621207,
#      'postalCode': '2150',
#      'state': 'NSW'},
#     'name': 'Choice Indian Fast food',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4c9d7b22031337047abf5fd5',
#     'location': {'address': '77 Wigram St,',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 135,
#      'formattedAddress': ['77 Wigram St,',
#       'Harris Park NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.82122745949484,
#        'lng': 151.0091837953755}],
#      'lat': -33.82122745949484,
#      'lng': 151.0091837953755,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': 'Chopsticks - Indian Chinese Cuisine',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4c4bd8f946240f47b45fe6f3',
#     'location': {'address': '94 Wigram St',
#      'cc': 'AU',
#      'country': 'Australia',
#      'crossStreet': 'at Ada St',
#      'distance': 175,
#      'formattedAddress': ['94 Wigram St (at Ada St)',
#       'Harris Park NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.820857107693314,
#        'lng': 151.0090824509468}],
#      'lat': -33.820857107693314,
#      'lng': 151.0090824509468,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': 'Ginger Indian Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4d75c18f74eca093f4fcb2a8',
#     'location': {'address': '67 Wigram Street',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 93,
#      'formattedAddress': ['67 Wigram Street', 'Harris Park NSW', 'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.821627,
#        'lng': 151.009254}],
#      'lat': -33.821627,
#      'lng': 151.009254,
#      'state': 'New South Wales'},
#     'name': 'Haveli Indian Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'primary': True,
#       'shortName': 'Supermarket'}],
#     'hasPerk': False,
#     'id': '536da5c0498e3a58b46f9642',
#     'location': {'cc': 'AU',
#      'country': 'Australia',
#      'distance': 116,
#      'formattedAddress': ['Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.821388,
#        'lng': 151.009084}],
#      'lat': -33.821388,
#      'lng': 151.009084},
#     'name': 'Sabzee Indian Supermarket',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '58e0621704f4d747c7c2dcf4',
#     'location': {'address': '42 Station Street East',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 218,
#      'formattedAddress': ['42 Station Street East',
#       'Harris Park NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.82058,
#        'lng': 151.00815}],
#      'lat': -33.82058,
#      'lng': 151.00815,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': "Grandmaa's Indian Restaurant",
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4e7f0452e5fa5ad2e5669c41',
#     'location': {'address': 'Suite 1/52 Station Street East, Harris Park',
#      'cc': 'AU',
#      'city': 'Parramatta',
#      'country': 'Australia',
#      'distance': 367,
#      'formattedAddress': ['Suite 1/52 Station Street East, Harris Park',
#       'Parramatta NSW 2150',
#       'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.819386849552856,
#        'lng': 151.00739961094294}],
#      'lat': -33.819386849552856,
#      'lng': 151.00739961094294,
#      'postalCode': '2150',
#      'state': 'NSW'},
#     'name': 'Celebrations Indian Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '59280b6204d1ae4b863fd066',
#     'location': {'cc': 'AU',
#      'city': 'Parramatta',
#      'country': 'Australia',
#      'distance': 541,
#      'formattedAddress': ['Parramatta NSW 2150', 'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.818548,
#        'lng': 151.005426}],
#      'lat': -33.818548,
#      'lng': 151.005426,
#      'postalCode': '2150',
#      'state': 'NSW'},
#     'name': 'Handi Lazeez Indian Restaurant',
#     'referralId': 'v-1557085419'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4ba5a789f964a520af1939e3',
#     'location': {'address': '62 Wigram St',
#      'cc': 'AU',
#      'country': 'Australia',
#      'distance': 56,
#      'formattedAddress': ['62 Wigram St', 'Harris Park NSW 2150', 'Australia'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.82192287901716,
#        'lng': 151.00895990866886}],
#      'lat': -33.82192287901716,
#      'lng': 151.00895990866886,
#      'postalCode': '2150',
#      'state': 'New South Wales'},
#     'name': "Billu's Eatery",
#     'referralId': 'v-1557085419'}]}}

# %% [markdown]
# Getting relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'id': '4bf58dd8d48988d10f94...    False
# 1  [{'primary': True, 'id': '54135bf5e4b08f3d2429...    False
# 2  [{'primary': True, 'id': '4bf58dd8d48988d10f94...    False
# 3  [{'primary': True, 'id': '4bf58dd8d48988d10f94...    False
# 4  [{'primary': True, 'id': '4bf58dd8d48988d10f94...    False
#
#                          id location.address location.cc location.city  \
# 0  4cd52943a5b34688b83a8c50     91 Wigram St          AU           NaN
# 1  5af7bd34838e59002c67158b    42 Marion st,          AU           NaN
# 2  530051d7498ef1d57b83a062     53 Marion St          AU        Sydney
# 3  4c9d7b22031337047abf5fd5    77 Wigram St,          AU           NaN
# 4  4c4bd8f946240f47b45fe6f3     94 Wigram St          AU           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0        Australia                  NaN                217
# 1        Australia                  NaN                 56
# 2        Australia          Harris Park                 61
# 3        Australia                  NaN                135
# 4        Australia            at Ada St                175
#
#                            location.formattedAddress  \
# 0    [91 Wigram St, Harris Park NSW 2150, Australia]
# 1   [42 Marion st,, Harris Park NSW 2150, Australia]
# 2  [53 Marion St (Harris Park), Sydney NSW 2150, ...
# 3   [77 Wigram St,, Harris Park NSW 2150, Australia]
# 4  [94 Wigram St (at Ada St), Harris Park NSW 215...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lng': 151.00948, 'label': 'display', 'lat':...    -33.820522
# 1  [{'lng': 151.0084, 'label': 'display', 'lat': ...    -33.822220
# 2  [{'lng': 151.0083261621207, 'label': 'display'...    -33.822266
# 3  [{'lng': 151.0091837953755, 'label': 'display'...    -33.821227
# 4  [{'lng': 151.0090824509468, 'label': 'display'...    -33.820857
#
#    location.lng location.postalCode   location.state  \
# 0    151.009480                2150  New South Wales
# 1    151.008400                2150  New South Wales
# 2    151.008326                2150              NSW
# 3    151.009184                2150  New South Wales
# 4    151.009082                2150  New South Wales
#
#                                   name    referralId
# 0       Taj Indian Sweets & Restaurant  v-1557085419
# 1         Amaravathi Indian Restaurant  v-1557085419
# 2              Choice Indian Fast food  v-1557085419
# 3  Chopsticks - Indian Chinese Cuisine  v-1557085419
# 4             Ginger Indian Restaurant  v-1557085419

# %% [markdown]
# Defining information of interest and filtering dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name               categories  \
# 0        Taj Indian Sweets & Restaurant        Indian Restaurant
# 1          Amaravathi Indian Restaurant  South Indian Restaurant
# 2               Choice Indian Fast food        Indian Restaurant
# 3   Chopsticks - Indian Chinese Cuisine        Indian Restaurant
# 4              Ginger Indian Restaurant        Indian Restaurant
# 5              Haveli Indian Restaurant        Indian Restaurant
# 6             Sabzee Indian Supermarket              Supermarket
# 7          Grandmaa's Indian Restaurant        Indian Restaurant
# 8        Celebrations Indian Restaurant        Indian Restaurant
# 9        Handi Lazeez Indian Restaurant        Indian Restaurant
# 10                       Billu's Eatery        Indian Restaurant
#
#                                         address  cc        city    country  \
# 0                                  91 Wigram St  AU         NaN  Australia
# 1                                 42 Marion st,  AU         NaN  Australia
# 2                                  53 Marion St  AU      Sydney  Australia
# 3                                 77 Wigram St,  AU         NaN  Australia
# 4                                  94 Wigram St  AU         NaN  Australia
# 5                              67 Wigram Street  AU         NaN  Australia
# 6                                           NaN  AU         NaN  Australia
# 7                        42 Station Street East  AU         NaN  Australia
# 8   Suite 1/52 Station Street East, Harris Park  AU  Parramatta  Australia
# 9                                           NaN  AU  Parramatta  Australia
# 10                                 62 Wigram St  AU         NaN  Australia
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       217    [91 Wigram St, Harris Park NSW 2150, Australia]
# 1           NaN        56   [42 Marion st,, Harris Park NSW 2150, Australia]
# 2   Harris Park        61  [53 Marion St (Harris Park), Sydney NSW 2150, ...
# 3           NaN       135   [77 Wigram St,, Harris Park NSW 2150, Australia]
# 4     at Ada St       175  [94 Wigram St (at Ada St), Harris Park NSW 215...
# 5           NaN        93     [67 Wigram Street, Harris Park NSW, Australia]
# 6           NaN       116                                        [Australia]
# 7           NaN       218  [42 Station Street East, Harris Park NSW 2150,...
# 8           NaN       367  [Suite 1/52 Station Street East, Harris Park, ...
# 9           NaN       541                   [Parramatta NSW 2150, Australia]
# 10          NaN        56    [62 Wigram St, Harris Park NSW 2150, Australia]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'lng': 151.00948, 'label': 'display', 'lat':... -33.820522  151.009480
# 1   [{'lng': 151.0084, 'label': 'display', 'lat': ... -33.822220  151.008400
# 2   [{'lng': 151.0083261621207, 'label': 'display'... -33.822266  151.008326
# 3   [{'lng': 151.0091837953755, 'label': 'display'... -33.821227  151.009184
# 4   [{'lng': 151.0090824509468, 'label': 'display'... -33.820857  151.009082
# 5   [{'lng': 151.009254, 'label': 'display', 'lat'... -33.821627  151.009254
# 6   [{'lng': 151.009084, 'label': 'display', 'lat'... -33.821388  151.009084
# 7   [{'lng': 151.00815, 'label': 'display', 'lat':... -33.820580  151.008150
# 8   [{'lng': 151.00739961094294, 'label': 'display... -33.819387  151.007400
# 9   [{'lng': 151.005426, 'label': 'display', 'lat'... -33.818548  151.005426
# 10  [{'lng': 151.00895990866886, 'label': 'display... -33.821923  151.008960
#
#    postalCode            state                        id
# 0        2150  New South Wales  4cd52943a5b34688b83a8c50
# 1        2150  New South Wales  5af7bd34838e59002c67158b
# 2        2150              NSW  530051d7498ef1d57b83a062
# 3        2150  New South Wales  4c9d7b22031337047abf5fd5
# 4        2150  New South Wales  4c4bd8f946240f47b45fe6f3
# 5         NaN  New South Wales  4d75c18f74eca093f4fcb2a8
# 6         NaN              NaN  536da5c0498e3a58b46f9642
# 7        2150  New South Wales  58e0621704f4d747c7c2dcf4
# 8        2150              NSW  4e7f0452e5fa5ad2e5669c41
# 9        2150              NSW  59280b6204d1ae4b863fd066
# 10       2150  New South Wales  4ba5a789f964a520af1939e3

# %% [markdown]
# Visualizing the venues that are nearby Parramatta suburb..

# %%
venues_map = folium.Map(location=[suburb_latitude, suburb_longitude], zoom_start=15) # generate map centred around Parramatta

# add a red circle marker to represent Parramatta
folium.features.CircleMarker(
    [suburb_latitude, suburb_longitude],
    radius=10,
    color='red',
    popup='Parramatta',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Indian restaurants/grocery stores as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=folium.Popup(label, parse_html=True),
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Now extending the same process to all the suburbs in Sydney using a function..

# %%
def getNearbyVenues(names, latitudes, longitudes, search_query = 'Indian', radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            lat, 
            lng, 
            VERSION, 
            search_query, 
            radius, 
            LIMIT)
            
        # make the GET request
        
        try:
            results = requests.get(url).json()['response']['venues']
            #print(results)
            #return only relevant information for each nearby venue
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['name'], 
                v['location']['lat'], 
                v['location']['lng'],  
                v['categories'][0]['name']) for v in results])
            #print(venues_list)
        except:
            pass
        
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Suburb', 
                  'Suburb Latitude', 
                  'Suburb Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    #return results
    #print(nearby_venues)
    return(nearby_venues)

# %%
sydney_venues = getNearbyVenues(names=df_sydney_suburbs['Suburb'],
                                   latitudes=df_sydney_suburbs['Latitude'],
                                   longitudes=df_sydney_suburbs['Longitude']
                                  )

# %%
print(sydney_venues.shape)
sydney_venues.head()
# Out:
# (240, 7)
#           Suburb  Suburb Latitude  Suburb Longitude                    Venue  \
# 0  Millers Point       -33.877718        151.205723  Mirchi Indian Malaysian
# 1  Millers Point       -33.877718        151.205723        Indian Excellency
# 2  Millers Point       -33.877718        151.205723           One Mb- Indian
# 3  Millers Point       -33.877718        151.205723       Nirvana New Indian
# 4  Millers Point       -33.877718        151.205723            Naked Indiana
#
#    Venue Latitude  Venue Longitude                 Venue Category
# 0      -33.876781       151.206917              Indian Restaurant
# 1      -33.877494       151.207670              Indian Restaurant
# 2      -33.879289       151.207960              Indian Restaurant
# 3      -33.874297       151.206900              Indian Restaurant
# 4      -33.880824       151.209604  Vegetarian / Vegan Restaurant

# %%
sydney_venues_map = folium.Map(location=[-33.8688, 151.2093], zoom_start=12) # generate map centred around Sydney

# add a red circle marker to represent suburbs
for lat, lng, label in zip(sydney_venues['Suburb Latitude'], sydney_venues['Suburb Longitude'], sydney_venues['Suburb']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color='red',
        popup=folium.Popup(label, parse_html=True),
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.6
    ).add_to(sydney_venues_map)

# add the Indian restaurants/grocery stores as blue circle markers
for lat, lng, label in zip(sydney_venues['Venue Latitude'], sydney_venues['Venue Longitude'], sydney_venues['Venue']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=folium.Popup(label, parse_html=True),
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(sydney_venues_map)
# display map
sydney_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
